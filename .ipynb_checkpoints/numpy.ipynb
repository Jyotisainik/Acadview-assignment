# %% [markdown]
# # Question 1.

# %%
import numpy
import numpy as np
e=np.random.random((10,1))
print(e)
print(e.mean())
# Out:
# [[0.51587087]
#  [0.01716461]
#  [0.03516141]
#  [0.80204489]
#  [0.86812205]
#  [0.58152204]
#  [0.26660219]
#  [0.94224303]
#  [0.01065894]
#  [0.75979067]]
# 0.4799180710456928

# %% [markdown]
# # Question 2.

# %%
e=np.random.random((20,1))
print(e)
print(e.std())
print(e.var())
# Out:
# [[0.48561539]
#  [0.02362797]
#  [0.35361526]
#  [0.81641489]
#  [0.66738376]
#  [0.97695154]
#  [0.45421627]
#  [0.52622739]
#  [0.30732651]
#  [0.19801401]
#  [0.58083664]
#  [0.87314166]
#  [0.37516924]
#  [0.68301513]
#  [0.47727749]
#  [0.42711737]
#  [0.71704692]
#  [0.90206783]
#  [0.45984968]
#  [0.79693282]]
# 0.24226092995805465
# 0.058690358184141464

# %% [markdown]
# # Question 3.

# %%
a=np.random.random((10,20))
print(a)
b=np.random.random((20,25))
print(b)
print(np.matmul(a,b))
n=np.random.random((10,25))
print(n)
print(n.sum())



#
# Out:
# [[0.01360206 0.51625715 0.8619961  0.19388949 0.35553227 0.36639629
#   0.7506986  0.70307433 0.56210117 0.4961438  0.70189641 0.33621427
#   0.32328531 0.51010642 0.01120984 0.27166661 0.75218171 0.83881875
#   0.44464294 0.13151365]
#  [0.73837376 0.64343565 0.26151232 0.49682511 0.76876895 0.78480348
#   0.44106081 0.83374214 0.53027584 0.21630157 0.99331656 0.77209241
#   0.21663668 0.88791931 0.57016067 0.89503117 0.99958636 0.10772535
#   0.98011678 0.7202352 ]
#  [0.75102201 0.37828761 0.62148102 0.92462854 0.22488823 0.25895555
#   0.63104883 0.95041513 0.50162377 0.83586569 0.21418347 0.92953859
#   0.29667341 0.47458502 0.03620092 0.59488453 0.08616785 0.69667439
#   0.31737606 0.08655281]
#  [0.48537145 0.82547942 0.59488402 0.28531044 0.07333735 0.0672878
#   0.36660316 0.7853113  0.92252258 0.60025504 0.88531906 0.32958595
#   0.99124265 0.73821349 0.10489612 0.82142969 0.62689513 0.72757732
#   0.39559539 0.67744956]
# ...

# %% [markdown]
# # Question 4.

# %%
def show(i):
    return(1 / (1 +np.exp(-a)))
b=[]
a=np.random.random((10,1))
print(a)
for i in a:
    ans=show(i)
    b.append(ans)
print(np.array(b))
